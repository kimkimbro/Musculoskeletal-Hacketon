# %% [markdown]
# # Pain

# %% [markdown]
# ### general

# %%
INPUT_SHAPE = (512, 512, 1)
OUTPUT_SIZE = 16
from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

def landmark_cnn(input_shape=INPUT_SHAPE, output_size=OUTPUT_SIZE):

    img_input = Input(shape=input_shape)
    

    x = Conv2D(16, (3,3), strides=(1,1), name='Conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv1')(x)
    
    x = MaxPooling2D(pool_size=(2,2), strides=(2,2), name='Pool1')(x)


    x = Conv2D(32, (3,3), strides=(1,1), name='Conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv2')(x)
    
    x = Conv2D(64, (3,3), strides=(1,1), name='Conv3')(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv3')(x)
    
    x = MaxPooling2D(pool_size=(2,2), strides=(2,2), name='Pool2')(x)


    x = Conv2D(32, (3,3), strides=(1,1), name='Conv4')(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv4')(x)
    
    x = Conv2D(32, (3,3), strides=(1,1), name='Conv5')(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv5')(x)
    
    x = MaxPooling2D(pool_size=(2,2), strides=(2,2), name='Pool3')(x)
        

    x = Conv2D(64, (3,3), strides=(1,1), name='Conv6')(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name='Relu_conv6')(x)
    
    x = Dropout(0.2)(x)
    
    x = Flatten(name='Flatten')(x)
    x = Dense(128, activation='relu', name='FC1')(x)
    x = Dense(output_size, activation=None, name='Predictions')(x)
    
    
    model = Model([img_input], x, name='Landmark_model')
    
    return model
model = landmark_cnn()
model.summary()
# Out:
# Model: "Landmark_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 512, 512, 1)]     0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 510, 510, 16)      160
# _________________________________________________________________
# batch_normalization_553 (Bat (None, 510, 510, 16)      64
# _________________________________________________________________
# Relu_conv1 (Activation)      (None, 510, 510, 16)      0
# _________________________________________________________________
# Pool1 (MaxPooling2D)         (None, 255, 255, 16)      0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 253, 253, 32)      4640
# _________________________________________________________________
# batch_normalization_554 (Bat (None, 253, 253, 32)      128
# _________________________________________________________________
# Relu_conv2 (Activation)      (None, 253, 253, 32)      0
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 251, 251, 64)      18496
# _________________________________________________________________
# batch_normalization_555 (Bat (None, 251, 251, 64)      256
# _________________________________________________________________
# Relu_conv3 (Activation)      (None, 251, 251, 64)      0
# _________________________________________________________________
# Pool2 (MaxPooling2D)         (None, 125, 125, 64)      0
# _________________________________________________________________
# Conv4 (Conv2D)               (None, 123, 123, 32)      18464
# _________________________________________________________________
# batch_normalization_556 (Bat (None, 123, 123, 32)      128
# _________________________________________________________________
# Relu_conv4 (Activation)      (None, 123, 123, 32)      0
# _________________________________________________________________
# Conv5 (Conv2D)               (None, 121, 121, 32)      9248
# _________________________________________________________________
# batch_normalization_557 (Bat (None, 121, 121, 32)      128
# _________________________________________________________________
# Relu_conv5 (Activation)      (None, 121, 121, 32)      0
# _________________________________________________________________
# Pool3 (MaxPooling2D)         (None, 60, 60, 32)        0
# _________________________________________________________________
# Conv6 (Conv2D)               (None, 58, 58, 64)        18496
# _________________________________________________________________
# batch_normalization_558 (Bat (None, 58, 58, 64)        256
# _________________________________________________________________
# Relu_conv6 (Activation)      (None, 58, 58, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 58, 58, 64)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 215296)            0
# _________________________________________________________________
# FC1 (Dense)                  (None, 128)               27558016
# _________________________________________________________________
# Predictions (Dense)          (None, 16)                2064
# =================================================================
# Total params: 27,630,544
# Trainable params: 27,630,064
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ### Kaggle-Face-key-detection

# %%
model = keras.Sequential()

model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(512, 512, 1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
# model.add(BatchNormalization())
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())


model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(16))
# Out:
# <class 'tensorflow.python.keras.engine.sequential.Sequential'>

# %% [markdown]
# ### Stacked-hourglass

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import mean_squared_error
import tensorflow.keras.backend as K


def create_hourglass_network(num_classes, num_stacks, num_channels, inres, outres, bottleneck):
    input = Input(shape=(inres[0], inres[1], 1))

    front_features = create_front_module(input, num_channels, bottleneck)

    head_next_stage = front_features

    outputs = []
    for i in range(num_stacks):
        head_next_stage, head_to_loss = hourglass_module(head_next_stage, num_classes, num_channels, bottleneck, i)
        outputs.append(head_to_loss)
        a = Flatten()(outputs[-1])
        a = Dense(num_classes, activation=None)(a)
        

    model = Model(inputs=input, outputs=a)
    rms = RMSprop(lr=5e-4)
    model.compile(optimizer=rms, loss=mean_squared_error, metrics=["accuracy"])
    
    

    return model


def hourglass_module(bottom, num_classes, num_channels, bottleneck, hgid):
    # create left features , f1, f2, f4, and f8
    left_features = create_left_half_blocks(bottom, bottleneck, hgid, num_channels)

    # create right features, connect with left features
    rf1 = create_right_half_blocks(left_features, bottleneck, hgid, num_channels)

    # add 1x1 conv with two heads, head_next_stage is sent to next stage
    # head_parts is used for intermediate supervision
    head_next_stage, head_parts = create_heads(bottom, rf1, num_classes, hgid, num_channels)

    return head_next_stage, head_parts


def bottleneck_block(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                       name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = Conv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def bottleneck_mobile(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                                name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                         name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def create_front_module(input, num_channels, bottleneck):
    # front module, input to 1/4 resolution
    # 1 7x7 conv + maxpooling
    # 3 residual block

    _x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same', activation='relu', name='front_conv_1x1_x1')(
        input)
    _x = BatchNormalization()(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x2')
    _x = bottleneck(_x, num_channels, 'front_residual_x3')

    return _x


def create_left_half_blocks(bottom, bottleneck, hglayer, num_channels):
    # create left half blocks for hourglass module
    # f1, f2, f4 , f8 : 1, 1/2, 1/4 1/8 resolution

    hgname = 'hg' + str(hglayer)

    f1 = bottleneck(bottom, num_channels, hgname + '_l1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f1)

    f2 = bottleneck(_x, num_channels, hgname + '_l2')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f2)

    f4 = bottleneck(_x, num_channels, hgname + '_l4')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f4)

    f8 = bottleneck(_x, num_channels, hgname + '_l8')

    return (f1, f2, f4, f8)


def connect_left_to_right(left, right, bottleneck, name, num_channels):
    '''
    :param left: connect left feature to right feature
    :param name: layer name
    :return:
    '''
    # left -> 1 bottlenect
    # right -> upsampling
    # Add   -> left + right

    _xleft = bottleneck(left, num_channels, name + '_connect')
    _xright = UpSampling2D()(right)
    add = Add()([_xleft, _xright])
    out = bottleneck(add, num_channels, name + '_connect_conv')
    return out


def bottom_layer(lf8, bottleneck, hgid, num_channels):
    # blocks in lowest resolution
    # 3 bottlenect blocks + Add

    lf8_connect = bottleneck(lf8, num_channels, str(hgid) + "_lf8")

    _x = bottleneck(lf8, num_channels, str(hgid) + "_lf8_x1")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x2")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x3")

    rf8 = Add()([_x, lf8_connect])

    return rf8


def create_right_half_blocks(leftfeatures, bottleneck, hglayer, num_channels):  #branch_add
    lf1, lf2, lf4, lf8 = leftfeatures

    rf8 = bottom_layer(lf8, bottleneck, hglayer, num_channels)

    rf4 = connect_left_to_right(lf4, rf8, bottleneck, 'hg' + str(hglayer) + '_rf4', num_channels)

    rf2 = connect_left_to_right(lf2, rf4, bottleneck, 'hg' + str(hglayer) + '_rf2', num_channels)

    rf1 = connect_left_to_right(lf1, rf2, bottleneck, 'hg' + str(hglayer) + '_rf1', num_channels)

    return rf1


def create_heads(prelayerfeatures, rf1, num_classes, hgid, num_channels):
    # two head, one head to next stage, one head to intermediate features
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='relu', padding='same', name=str(hgid) + '_conv_1x1_x1')(
        rf1)
    head = BatchNormalization()(head)

    # for head as intermediate supervision, use 'linear' as activation.
    head_parts = Conv2D(num_classes, kernel_size=(1, 1), activation='linear', padding='same',
                        name=str(hgid) + '_conv_1x1_parts')(head)

    # use linear activation
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                  name=str(hgid) + '_conv_1x1_x2')(head)
    head_m = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                    name=str(hgid) + '_conv_1x1_x3')(head_parts)

    head_next_stage = Add()([head, head_m, prelayerfeatures])
    return head_next_stage, head_parts


def euclidean_loss(x, y):
    return K.sqrt(K.sum(K.square(x - y)))

# %%
model = create_hourglass_network(num_classes=16, num_stacks=1, num_channels=16 , inres=(512, 512),
                            outres=(1,1), bottleneck=bottleneck_block)

# %%
model.summary()
# Out:
# Model: "functional_39"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_30 (InputLayer)           [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# front_conv_1x1_x1 (Conv2D)      (None, 256, 256, 64) 3200        input_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1619 (Batch (None, 256, 256, 64) 256         front_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x1 ( (None, 256, 256, 4)  260         batch_normalization_1619[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1620 (Batch (None, 256, 256, 4)  16          front_residual_x1_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_3x3_x2 ( (None, 256, 256, 4)  148         batch_normalization_1620[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1621 (Batch (None, 256, 256, 4)  16          front_residual_x1_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x3 ( (None, 256, 256, 8)  40          batch_normalization_1621[0][0]
# __________________________________________________________________________________________________
# front_residual_x1skip (Conv2D)  (None, 256, 256, 8)  520         batch_normalization_1619[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1622 (Batch (None, 256, 256, 8)  32          front_residual_x1_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x1_residual (Add (None, 256, 256, 8)  0           front_residual_x1skip[0][0]
#                                                                  batch_normalization_1622[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_121 (MaxPooling2D (None, 128, 128, 8)  0           front_residual_x1_residual[0][0]
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x1 ( (None, 128, 128, 4)  36          max_pooling2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1623 (Batch (None, 128, 128, 4)  16          front_residual_x2_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_3x3_x2 ( (None, 128, 128, 4)  148         batch_normalization_1623[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1624 (Batch (None, 128, 128, 4)  16          front_residual_x2_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x3 ( (None, 128, 128, 8)  40          batch_normalization_1624[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1625 (Batch (None, 128, 128, 8)  32          front_residual_x2_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x2_residual (Add (None, 128, 128, 8)  0           max_pooling2d_121[0][0]
#                                                                  batch_normalization_1625[0][0]
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x1 ( (None, 128, 128, 8)  72          front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1626 (Batch (None, 128, 128, 8)  32          front_residual_x3_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_3x3_x2 ( (None, 128, 128, 8)  584         batch_normalization_1626[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1627 (Batch (None, 128, 128, 8)  32          front_residual_x3_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x3 ( (None, 128, 128, 16) 144         batch_normalization_1627[0][0]
# __________________________________________________________________________________________________
# front_residual_x3skip (Conv2D)  (None, 128, 128, 16) 144         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1628 (Batch (None, 128, 128, 16) 64          front_residual_x3_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x3_residual (Add (None, 128, 128, 16) 0           front_residual_x3skip[0][0]
#                                                                  batch_normalization_1628[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x1 (Conv2D)     (None, 128, 128, 8)  136         front_residual_x3_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1629 (Batch (None, 128, 128, 8)  32          hg0_l1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_3x3_x2 (Conv2D)     (None, 128, 128, 8)  584         batch_normalization_1629[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1630 (Batch (None, 128, 128, 8)  32          hg0_l1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x3 (Conv2D)     (None, 128, 128, 16) 144         batch_normalization_1630[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1631 (Batch (None, 128, 128, 16) 64          hg0_l1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l1_residual (Add)           (None, 128, 128, 16) 0           front_residual_x3_residual[0][0]
#                                                                  batch_normalization_1631[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_122 (MaxPooling2D (None, 64, 64, 16)   0           hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x1 (Conv2D)     (None, 64, 64, 8)    136         max_pooling2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1632 (Batch (None, 64, 64, 8)    32          hg0_l2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_3x3_x2 (Conv2D)     (None, 64, 64, 8)    584         batch_normalization_1632[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1633 (Batch (None, 64, 64, 8)    32          hg0_l2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x3 (Conv2D)     (None, 64, 64, 16)   144         batch_normalization_1633[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1634 (Batch (None, 64, 64, 16)   64          hg0_l2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l2_residual (Add)           (None, 64, 64, 16)   0           max_pooling2d_122[0][0]
#                                                                  batch_normalization_1634[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_123 (MaxPooling2D (None, 32, 32, 16)   0           hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x1 (Conv2D)     (None, 32, 32, 8)    136         max_pooling2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1635 (Batch (None, 32, 32, 8)    32          hg0_l4_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_3x3_x2 (Conv2D)     (None, 32, 32, 8)    584         batch_normalization_1635[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1636 (Batch (None, 32, 32, 8)    32          hg0_l4_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x3 (Conv2D)     (None, 32, 32, 16)   144         batch_normalization_1636[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1637 (Batch (None, 32, 32, 16)   64          hg0_l4_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l4_residual (Add)           (None, 32, 32, 16)   0           max_pooling2d_123[0][0]
#                                                                  batch_normalization_1637[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_124 (MaxPooling2D (None, 16, 16, 16)   0           hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x1 (Conv2D)     (None, 16, 16, 8)    136         max_pooling2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1638 (Batch (None, 16, 16, 8)    32          hg0_l8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_3x3_x2 (Conv2D)     (None, 16, 16, 8)    584         batch_normalization_1638[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1639 (Batch (None, 16, 16, 8)    32          hg0_l8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x3 (Conv2D)     (None, 16, 16, 16)   144         batch_normalization_1639[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1640 (Batch (None, 16, 16, 16)   64          hg0_l8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l8_residual (Add)           (None, 16, 16, 16)   0           max_pooling2d_124[0][0]
#                                                                  batch_normalization_1640[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x1 (Conv2D)   (None, 16, 16, 8)    136         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1644 (Batch (None, 16, 16, 8)    32          0_lf8_x1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_3x3_x2 (Conv2D)   (None, 16, 16, 8)    584         batch_normalization_1644[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1645 (Batch (None, 16, 16, 8)    32          0_lf8_x1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x3 (Conv2D)   (None, 16, 16, 16)   144         batch_normalization_1645[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1646 (Batch (None, 16, 16, 16)   64          0_lf8_x1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_residual (Add)         (None, 16, 16, 16)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_1646[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x1 (Conv2D)   (None, 16, 16, 8)    136         0_lf8_x1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1647 (Batch (None, 16, 16, 8)    32          0_lf8_x2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_3x3_x2 (Conv2D)   (None, 16, 16, 8)    584         batch_normalization_1647[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1648 (Batch (None, 16, 16, 8)    32          0_lf8_x2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x3 (Conv2D)   (None, 16, 16, 16)   144         batch_normalization_1648[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1649 (Batch (None, 16, 16, 16)   64          0_lf8_x2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_residual (Add)         (None, 16, 16, 16)   0           0_lf8_x1_residual[0][0]
#                                                                  batch_normalization_1649[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x1 (Conv2D)   (None, 16, 16, 8)    136         0_lf8_x2_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x1 (Conv2D)      (None, 16, 16, 8)    136         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1650 (Batch (None, 16, 16, 8)    32          0_lf8_x3_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1641 (Batch (None, 16, 16, 8)    32          0_lf8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x1 (Co (None, 32, 32, 8)    136         hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_3x3_x2 (Conv2D)   (None, 16, 16, 8)    584         batch_normalization_1650[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_3x3_x2 (Conv2D)      (None, 16, 16, 8)    584         batch_normalization_1641[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1653 (Batch (None, 32, 32, 8)    32          hg0_rf4_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1651 (Batch (None, 16, 16, 8)    32          0_lf8_x3_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1642 (Batch (None, 16, 16, 8)    32          0_lf8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_3x3_x2 (Co (None, 32, 32, 8)    584         batch_normalization_1653[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x3 (Conv2D)   (None, 16, 16, 16)   144         batch_normalization_1651[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x3 (Conv2D)      (None, 16, 16, 16)   144         batch_normalization_1642[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1654 (Batch (None, 32, 32, 8)    32          hg0_rf4_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1652 (Batch (None, 16, 16, 16)   64          0_lf8_x3_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1643 (Batch (None, 16, 16, 16)   64          0_lf8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x3 (Co (None, 32, 32, 16)   144         batch_normalization_1654[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_residual (Add)         (None, 16, 16, 16)   0           0_lf8_x2_residual[0][0]
#                                                                  batch_normalization_1652[0][0]
# __________________________________________________________________________________________________
# 0_lf8_residual (Add)            (None, 16, 16, 16)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_1643[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1655 (Batch (None, 32, 32, 16)   64          hg0_rf4_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 16, 16, 16)   0           0_lf8_x3_residual[0][0]
#                                                                  0_lf8_residual[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_residual (Add)  (None, 32, 32, 16)   0           hg0_l4_residual[0][0]
#                                                                  batch_normalization_1655[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_93 (UpSampling2D) (None, 32, 32, 16)   0           add_155[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 32, 32, 16)   0           hg0_rf4_connect_residual[0][0]
#                                                                  up_sampling2d_93[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 8)    136         add_156[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x1 (Co (None, 64, 64, 8)    136         hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1656 (Batch (None, 32, 32, 8)    32          hg0_rf4_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_1659 (Batch (None, 64, 64, 8)    32          hg0_rf2_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_3x3_x (None, 32, 32, 8)    584         batch_normalization_1656[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_3x3_x2 (Co (None, 64, 64, 8)    584         batch_normalization_1659[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1657 (Batch (None, 32, 32, 8)    32          hg0_rf4_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_1660 (Batch (None, 64, 64, 8)    32          hg0_rf2_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 16)   144         batch_normalization_1657[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x3 (Co (None, 64, 64, 16)   144         batch_normalization_1660[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1658 (Batch (None, 32, 32, 16)   64          hg0_rf4_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_1661 (Batch (None, 64, 64, 16)   64          hg0_rf2_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_residual ( (None, 32, 32, 16)   0           add_156[0][0]
#                                                                  batch_normalization_1658[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_residual (Add)  (None, 64, 64, 16)   0           hg0_l2_residual[0][0]
#                                                                  batch_normalization_1661[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_94 (UpSampling2D) (None, 64, 64, 16)   0           hg0_rf4_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 64, 64, 16)   0           hg0_rf2_connect_residual[0][0]
#                                                                  up_sampling2d_94[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 8)    136         add_157[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x1 (Co (None, 128, 128, 8)  136         hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1662 (Batch (None, 64, 64, 8)    32          hg0_rf2_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_1665 (Batch (None, 128, 128, 8)  32          hg0_rf1_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_3x3_x (None, 64, 64, 8)    584         batch_normalization_1662[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_3x3_x2 (Co (None, 128, 128, 8)  584         batch_normalization_1665[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1663 (Batch (None, 64, 64, 8)    32          hg0_rf2_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_1666 (Batch (None, 128, 128, 8)  32          hg0_rf1_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 16)   144         batch_normalization_1663[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x3 (Co (None, 128, 128, 16) 144         batch_normalization_1666[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1664 (Batch (None, 64, 64, 16)   64          hg0_rf2_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_1667 (Batch (None, 128, 128, 16) 64          hg0_rf1_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_residual ( (None, 64, 64, 16)   0           add_157[0][0]
#                                                                  batch_normalization_1664[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_residual (Add)  (None, 128, 128, 16) 0           hg0_l1_residual[0][0]
#                                                                  batch_normalization_1667[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_95 (UpSampling2D) (None, 128, 128, 16) 0           hg0_rf2_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 128, 128, 16) 0           hg0_rf1_connect_residual[0][0]
#                                                                  up_sampling2d_95[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 8)  136         add_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1668 (Batch (None, 128, 128, 8)  32          hg0_rf1_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_3x3_x (None, 128, 128, 8)  584         batch_normalization_1668[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1669 (Batch (None, 128, 128, 8)  32          hg0_rf1_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 16) 144         batch_normalization_1669[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1670 (Batch (None, 128, 128, 16) 64          hg0_rf1_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_residual ( (None, 128, 128, 16) 0           add_158[0][0]
#                                                                  batch_normalization_1670[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_x1 (Conv2D)          (None, 128, 128, 16) 272         hg0_rf1_connect_conv_residual[0][
# __________________________________________________________________________________________________
# batch_normalization_1671 (Batch (None, 128, 128, 16) 64          0_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_parts (Conv2D)       (None, 128, 128, 16) 272         batch_normalization_1671[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 262144)       0           0_conv_1x1_parts[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           4194320     flatten_11[0][0]
# ==================================================================================================
# Total params: 4,214,664
# Trainable params: 4,213,480
# Non-trainable params: 1,184
# __________________________________________________________________________________________________
