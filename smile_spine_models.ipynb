# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, Cropping2D, concatenate, Activation,Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import *

def get_unet(img_rows, img_cols):
    
    
    inputs = Input((img_rows, img_cols,1))
    conv1 = Conv2D(32, (3, 3), activation=None, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(32, (3, 3), activation=None, padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation=None, padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(64, (3, 3), activation=None, padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation=None, padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(128, (3, 3), activation=None, padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation=None, padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(256, (3, 3), activation=None, padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation=None, padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(512, (3, 3), activation=None, padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation=None, padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(256, (3, 3), activation=None, padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation=None, padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(128, (3, 3), activation=None, padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation=None, padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(64, (3, 3), activation=None, padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation=None, padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(32, (3, 3), activation=None, padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    return model

# %%
img_rows = 512
img_cols = 512

model = get_unet(img_rows, img_cols)
model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 512, 512, 32) 320         input_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 512, 512, 32) 128         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 512, 512, 32) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 512, 512, 32) 9248        activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 512, 512, 32) 128         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 512, 512, 32) 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 256, 256, 32) 0           activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 64) 18496       max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 256, 256, 64) 256         conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 256, 256, 64) 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 64) 36928       activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 256, 256, 64) 256         conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 256, 256, 64) 0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 128, 128, 64) 0           activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 128, 128, 128 73856       max_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 128, 128, 128 512         conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 128, 128, 128 0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 128, 128, 128 147584      activation_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 128, 128, 128 512         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 128, 128, 128 0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D) (None, 64, 64, 128)  0           activation_137[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 64, 64, 256)  295168      max_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 64, 64, 256)  1024        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 64, 64, 256)  0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 64, 64, 256)  590080      activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 64, 64, 256)  1024        conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 64, 64, 256)  0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D) (None, 32, 32, 256)  0           activation_139[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 32, 32, 512)  1180160     max_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 32, 32, 512)  2048        conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 32, 32, 512)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 32, 32, 512)  2359808     activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 32, 32, 512)  2048        conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 32, 32, 512)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 256)  524544      activation_141[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_11[0][0]
#                                                                  activation_139[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 64, 64, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 64, 64, 256)  1024        conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 64, 64, 256)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 64, 64, 256)  590080      activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 64, 64, 256)  1024        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 64, 64, 256)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 128, 128, 128 131200      activation_143[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 256 0           conv2d_transpose_12[0][0]
#                                                                  activation_137[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 128, 128, 128 295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 128, 128, 128 512         conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 128, 128, 128 0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 128, 128, 128 147584      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 128, 128, 128 512         conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 128, 128, 128 0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 256, 256, 64) 32832       activation_145[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 128 0           conv2d_transpose_13[0][0]
#                                                                  activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 256, 256, 64) 73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 256, 256, 64) 256         conv2d_147[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 256, 256, 64) 0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 256, 256, 64) 36928       activation_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 256, 256, 64) 256         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 256, 256, 64) 0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 512, 512, 32) 8224        activation_147[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 512, 512, 64) 0           conv2d_transpose_14[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 512, 512, 32) 18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 512, 512, 32) 128         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 512, 512, 32) 0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 512, 512, 32) 9248        activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 512, 512, 32) 128         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 512, 512, 32) 0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 512, 512, 1)  33          activation_149[0][0]
# ==================================================================================================
# Total params: 7,771,297
# Trainable params: 7,765,409
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Stacked hourglass-1

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import mean_squared_error
import tensorflow.keras.backend as K


def create_hourglass_network(num_classes, num_stacks, num_channels, inres, outres, bottleneck):
    input = Input(shape=(inres[0], inres[1], 1))

    front_features = create_front_module(input, num_channels, bottleneck)

    head_next_stage = front_features

    outputs = []
    for i in range(num_stacks):
        head_next_stage, head_to_loss = hourglass_module(head_next_stage, num_classes, num_channels, bottleneck, i)
        outputs.append(head_to_loss)
    
    a = BatchNormalization()(outputs[-1])
    a = Conv2DTranspose(num_classes/2, (2, 2), strides=(2, 2), padding='same')(a)
    a = BatchNormalization()(a)
    a = Conv2DTranspose(num_classes/4, (2, 2), strides=(2, 2), padding='same')(a)
    a = BatchNormalization()(a)
    a = Conv2D(1, (1, 1), activation='sigmoid')(a)
    
    model = Model(inputs=input, outputs=a)

    return model


def hourglass_module(bottom, num_classes, num_channels, bottleneck, hgid):
    # create left features , f1, f2, f4, and f8
    left_features = create_left_half_blocks(bottom, bottleneck, hgid, num_channels)

    # create right features, connect with left features
    rf1 = create_right_half_blocks(left_features, bottleneck, hgid, num_channels)

    # add 1x1 conv with two heads, head_next_stage is sent to next stage
    # head_parts is used for intermediate supervision
    head_next_stage, head_parts = create_heads(bottom, rf1, num_classes, hgid, num_channels)

    return head_next_stage, head_parts


def bottleneck_block(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                       name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = Conv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def bottleneck_mobile(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                                name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                         name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def create_front_module(input, num_channels, bottleneck):
    # front module, input to 1/4 resolution
    # 1 7x7 conv + maxpooling
    # 3 residual block

    _x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same', activation='relu', name='front_conv_1x1_x1')(
        input)
    _x = BatchNormalization()(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x2')
    _x = bottleneck(_x, num_channels, 'front_residual_x3')

    return _x


def create_left_half_blocks(bottom, bottleneck, hglayer, num_channels):
    # create left half blocks for hourglass module
    # f1, f2, f4 , f8 : 1, 1/2, 1/4 1/8 resolution

    hgname = 'hg' + str(hglayer)

    f1 = bottleneck(bottom, num_channels, hgname + '_l1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f1)

    f2 = bottleneck(_x, num_channels, hgname + '_l2')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f2)

    f4 = bottleneck(_x, num_channels, hgname + '_l4')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f4)

    f8 = bottleneck(_x, num_channels, hgname + '_l8')

    return (f1, f2, f4, f8)


def connect_left_to_right(left, right, bottleneck, name, num_channels):
    '''
    :param left: connect left feature to right feature
    :param name: layer name
    :return:
    '''
    # left -> 1 bottlenect
    # right -> upsampling
    # Add   -> left + right

    _xleft = bottleneck(left, num_channels, name + '_connect')
    _xright = UpSampling2D()(right)
    add = Add()([_xleft, _xright])
    out = bottleneck(add, num_channels, name + '_connect_conv')
    return out


def bottom_layer(lf8, bottleneck, hgid, num_channels):
    # blocks in lowest resolution
    # 3 bottlenect blocks + Add

    lf8_connect = bottleneck(lf8, num_channels, str(hgid) + "_lf8")

    _x = bottleneck(lf8, num_channels, str(hgid) + "_lf8_x1")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x2")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x3")

    rf8 = Add()([_x, lf8_connect])

    return rf8


def create_right_half_blocks(leftfeatures, bottleneck, hglayer, num_channels):  #branch_add
    lf1, lf2, lf4, lf8 = leftfeatures

    rf8 = bottom_layer(lf8, bottleneck, hglayer, num_channels)

    rf4 = connect_left_to_right(lf4, rf8, bottleneck, 'hg' + str(hglayer) + '_rf4', num_channels)

    rf2 = connect_left_to_right(lf2, rf4, bottleneck, 'hg' + str(hglayer) + '_rf2', num_channels)

    rf1 = connect_left_to_right(lf1, rf2, bottleneck, 'hg' + str(hglayer) + '_rf1', num_channels)

    return rf1


def create_heads(prelayerfeatures, rf1, num_classes, hgid, num_channels):
    # two head, one head to next stage, one head to intermediate features
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='relu', padding='same', name=str(hgid) + '_conv_1x1_x1')(
        rf1)
    head = BatchNormalization()(head)

    # for head as intermediate supervision, use 'linear' as activation.
    head_parts = Conv2D(num_classes, kernel_size=(1, 1), activation='linear', padding='same',
                        name=str(hgid) + '_conv_1x1_parts')(head)

    # use linear activation
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                  name=str(hgid) + '_conv_1x1_x2')(head)
    head_m = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                    name=str(hgid) + '_conv_1x1_x3')(head_parts)

    head_next_stage = Add()([head, head_m, prelayerfeatures])
    return head_next_stage, head_parts

# %%
model = create_hourglass_network(num_classes=16, num_stacks=1, num_channels=32 , inres=(512, 512),
                            outres=(1,1), bottleneck=bottleneck_block)

# %%
model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# front_conv_1x1_x1 (Conv2D)      (None, 256, 256, 64) 3200        input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 256, 256, 64) 256         front_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x1 ( (None, 256, 256, 8)  520         batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 256, 256, 8)  32          front_residual_x1_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_3x3_x2 ( (None, 256, 256, 8)  584         batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 256, 256, 8)  32          front_residual_x1_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x3 ( (None, 256, 256, 16) 144         batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# front_residual_x1skip (Conv2D)  (None, 256, 256, 16) 1040        batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 256, 256, 16) 64          front_residual_x1_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x1_residual (Add (None, 256, 256, 16) 0           front_residual_x1skip[0][0]
#                                                                  batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 128, 128, 16) 0           front_residual_x1_residual[0][0]
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x1 ( (None, 128, 128, 8)  136         max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 128, 128, 8)  32          front_residual_x2_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_3x3_x2 ( (None, 128, 128, 8)  584         batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 128, 128, 8)  32          front_residual_x2_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x3 ( (None, 128, 128, 16) 144         batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 128, 128, 16) 64          front_residual_x2_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x2_residual (Add (None, 128, 128, 16) 0           max_pooling2d_12[0][0]
#                                                                  batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x1 ( (None, 128, 128, 16) 272         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 128, 128, 16) 64          front_residual_x3_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_3x3_x2 ( (None, 128, 128, 16) 2320        batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 128, 128, 16) 64          front_residual_x3_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x3 ( (None, 128, 128, 32) 544         batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# front_residual_x3skip (Conv2D)  (None, 128, 128, 32) 544         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 128, 128, 32) 128         front_residual_x3_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x3_residual (Add (None, 128, 128, 32) 0           front_residual_x3skip[0][0]
#                                                                  batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x1 (Conv2D)     (None, 128, 128, 16) 528         front_residual_x3_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 128, 128, 16) 64          hg0_l1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_3x3_x2 (Conv2D)     (None, 128, 128, 16) 2320        batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 128, 128, 16) 64          hg0_l1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x3 (Conv2D)     (None, 128, 128, 32) 544         batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 128, 128, 32) 128         hg0_l1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l1_residual (Add)           (None, 128, 128, 32) 0           front_residual_x3_residual[0][0]
#                                                                  batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 64, 64, 32)   0           hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x1 (Conv2D)     (None, 64, 64, 16)   528         max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 64, 64, 16)   64          hg0_l2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_3x3_x2 (Conv2D)     (None, 64, 64, 16)   2320        batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 64, 64, 16)   64          hg0_l2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x3 (Conv2D)     (None, 64, 64, 32)   544         batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 64, 64, 32)   128         hg0_l2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l2_residual (Add)           (None, 64, 64, 32)   0           max_pooling2d_13[0][0]
#                                                                  batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 32, 32, 32)   0           hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x1 (Conv2D)     (None, 32, 32, 16)   528         max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 32, 32, 16)   64          hg0_l4_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_3x3_x2 (Conv2D)     (None, 32, 32, 16)   2320        batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 32, 32, 16)   64          hg0_l4_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x3 (Conv2D)     (None, 32, 32, 32)   544         batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 32, 32, 32)   128         hg0_l4_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l4_residual (Add)           (None, 32, 32, 32)   0           max_pooling2d_14[0][0]
#                                                                  batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 32)   0           hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x1 (Conv2D)     (None, 16, 16, 16)   528         max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 16, 16, 16)   64          hg0_l8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_3x3_x2 (Conv2D)     (None, 16, 16, 16)   2320        batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 16, 16, 16)   64          hg0_l8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x3 (Conv2D)     (None, 16, 16, 32)   544         batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 16, 16, 32)   128         hg0_l8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l8_residual (Add)           (None, 16, 16, 32)   0           max_pooling2d_15[0][0]
#                                                                  batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 16, 16, 16)   64          0_lf8_x1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 16, 16, 16)   64          0_lf8_x1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 16, 16, 32)   128         0_lf8_x1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_residual (Add)         (None, 16, 16, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         0_lf8_x1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 16, 16, 16)   64          0_lf8_x2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 16, 16, 16)   64          0_lf8_x2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 16, 16, 32)   128         0_lf8_x2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_residual (Add)         (None, 16, 16, 32)   0           0_lf8_x1_residual[0][0]
#                                                                  batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         0_lf8_x2_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x1 (Conv2D)      (None, 16, 16, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 16, 16, 16)   64          0_lf8_x3_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 16, 16, 16)   64          0_lf8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x1 (Co (None, 32, 32, 16)   528         hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_3x3_x2 (Conv2D)      (None, 16, 16, 16)   2320        batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 32, 32, 16)   64          hg0_rf4_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 16, 16, 16)   64          0_lf8_x3_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 16, 16, 16)   64          0_lf8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_3x3_x2 (Co (None, 32, 32, 16)   2320        batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x3 (Conv2D)      (None, 16, 16, 32)   544         batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 32, 32, 16)   64          hg0_rf4_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 16, 16, 32)   128         0_lf8_x3_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 16, 16, 32)   128         0_lf8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x3 (Co (None, 32, 32, 32)   544         batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_residual (Add)         (None, 16, 16, 32)   0           0_lf8_x2_residual[0][0]
#                                                                  batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# 0_lf8_residual (Add)            (None, 16, 16, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 32, 32, 32)   128         hg0_rf4_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 32)   0           0_lf8_x3_residual[0][0]
#                                                                  0_lf8_residual[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_residual (Add)  (None, 32, 32, 32)   0           hg0_l4_residual[0][0]
#                                                                  batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 32)   0           hg0_rf4_connect_residual[0][0]
#                                                                  up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 16)   528         add_16[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x1 (Co (None, 64, 64, 16)   528         hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 32, 32, 16)   64          hg0_rf4_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 64, 64, 16)   64          hg0_rf2_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_3x3_x (None, 32, 32, 16)   2320        batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_3x3_x2 (Co (None, 64, 64, 16)   2320        batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 32, 32, 16)   64          hg0_rf4_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 64, 64, 16)   64          hg0_rf2_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 32)   544         batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x3 (Co (None, 64, 64, 32)   544         batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 32, 32, 32)   128         hg0_rf4_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 64, 64, 32)   128         hg0_rf2_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_residual ( (None, 32, 32, 32)   0           add_16[0][0]
#                                                                  batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_residual (Add)  (None, 64, 64, 32)   0           hg0_l2_residual[0][0]
#                                                                  batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 64, 64, 32)   0           hg0_rf4_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 32)   0           hg0_rf2_connect_residual[0][0]
#                                                                  up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 16)   528         add_17[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x1 (Co (None, 128, 128, 16) 528         hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 64, 64, 16)   64          hg0_rf2_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 128, 128, 16) 64          hg0_rf1_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_3x3_x (None, 64, 64, 16)   2320        batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_3x3_x2 (Co (None, 128, 128, 16) 2320        batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 64, 64, 16)   64          hg0_rf2_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 128, 128, 16) 64          hg0_rf1_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 32)   544         batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x3 (Co (None, 128, 128, 32) 544         batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 64, 64, 32)   128         hg0_rf2_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 128, 128, 32) 128         hg0_rf1_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_residual ( (None, 64, 64, 32)   0           add_17[0][0]
#                                                                  batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_residual (Add)  (None, 128, 128, 32) 0           hg0_l1_residual[0][0]
#                                                                  batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 128, 128, 32) 0           hg0_rf2_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 128, 128, 32) 0           hg0_rf1_connect_residual[0][0]
#                                                                  up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 16) 528         add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 128, 128, 16) 64          hg0_rf1_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_3x3_x (None, 128, 128, 16) 2320        batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 128, 128, 16) 64          hg0_rf1_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 32) 544         batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 128, 128, 32) 128         hg0_rf1_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_residual ( (None, 128, 128, 32) 0           add_18[0][0]
#                                                                  batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_x1 (Conv2D)          (None, 128, 128, 32) 1056        hg0_rf1_connect_conv_residual[0][
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 128, 128, 32) 128         0_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_parts (Conv2D)       (None, 128, 128, 16) 528         batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 128, 128, 16) 64          0_conv_1x1_parts[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 256, 256, 8)  520         batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 256, 256, 8)  32          conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 512, 512, 4)  132         batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 512, 512, 4)  16          conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 512, 512, 1)  5           batch_normalization_223[0][0]
# ==================================================================================================
# Total params: 64,353
# Trainable params: 62,057
# Non-trainable params: 2,296
# __________________________________________________________________________________________________

# %% [markdown]
# # Stacked hourglass-2

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import mean_squared_error
import tensorflow.keras.backend as K


def create_hourglass_network(num_classes, num_stacks, num_channels, inres, outres, bottleneck):
    input = Input(shape=(inres[0], inres[1], 1))

    front_features = create_front_module(input, num_channels, bottleneck)

    head_next_stage = front_features

    outputs = []
    for i in range(num_stacks):
        head_next_stage, head_to_loss = hourglass_module(head_next_stage, num_classes, num_channels, bottleneck, i)
        outputs.append(head_to_loss)
    
    a = BatchNormalization()(outputs[-1])

    a = Conv2D(1, (1, 1), activation='sigmoid')(a)
    
    model = Model(inputs=input, outputs=a)

    return model


def hourglass_module(bottom, num_classes, num_channels, bottleneck, hgid):
    # create left features , f1, f2, f4, and f8
    left_features = create_left_half_blocks(bottom, bottleneck, hgid, num_channels)

    # create right features, connect with left features
    rf1 = create_right_half_blocks(left_features, bottleneck, hgid, num_channels)

    # add 1x1 conv with two heads, head_next_stage is sent to next stage
    # head_parts is used for intermediate supervision
    head_next_stage, head_parts = create_heads(bottom, rf1, num_classes, hgid, num_channels)

    return head_next_stage, head_parts


def bottleneck_block(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                       name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = Conv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def bottleneck_mobile(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                                name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                         name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def create_front_module(input, num_channels, bottleneck):
    
    _x = input

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x1')
    _x = bottleneck(_x, num_channels // 2, 'front_residual_x2')
    _x = bottleneck(_x, num_channels, 'front_residual_x3')

    return _x


def create_left_half_blocks(bottom, bottleneck, hglayer, num_channels):
    # create left half blocks for hourglass module
    # f1, f2, f4 , f8 : 1, 1/2, 1/4 1/8 resolution

    hgname = 'hg' + str(hglayer)

    f1 = bottleneck(bottom, num_channels, hgname + '_l1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f1)

    f2 = bottleneck(_x, num_channels, hgname + '_l2')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f2)

    f4 = bottleneck(_x, num_channels, hgname + '_l4')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f4)

    f8 = bottleneck(_x, num_channels, hgname + '_l8')

    return (f1, f2, f4, f8)


def connect_left_to_right(left, right, bottleneck, name, num_channels):
    '''
    :param left: connect left feature to right feature
    :param name: layer name
    :return:
    '''
    # left -> 1 bottlenect
    # right -> upsampling
    # Add   -> left + right

    _xleft = bottleneck(left, num_channels, name + '_connect')
    _xright = UpSampling2D()(right)
    add = Add()([_xleft, _xright])
    out = bottleneck(add, num_channels, name + '_connect_conv')
    return out


def bottom_layer(lf8, bottleneck, hgid, num_channels):
    # blocks in lowest resolution
    # 3 bottlenect blocks + Add

    lf8_connect = bottleneck(lf8, num_channels, str(hgid) + "_lf8")

    _x = bottleneck(lf8, num_channels, str(hgid) + "_lf8_x1")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x2")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x3")

    rf8 = Add()([_x, lf8_connect])

    return rf8


def create_right_half_blocks(leftfeatures, bottleneck, hglayer, num_channels):  #branch_add
    lf1, lf2, lf4, lf8 = leftfeatures

    rf8 = bottom_layer(lf8, bottleneck, hglayer, num_channels)

    rf4 = connect_left_to_right(lf4, rf8, bottleneck, 'hg' + str(hglayer) + '_rf4', num_channels)

    rf2 = connect_left_to_right(lf2, rf4, bottleneck, 'hg' + str(hglayer) + '_rf2', num_channels)

    rf1 = connect_left_to_right(lf1, rf2, bottleneck, 'hg' + str(hglayer) + '_rf1', num_channels)

    return rf1


def create_heads(prelayerfeatures, rf1, num_classes, hgid, num_channels):
    # two head, one head to next stage, one head to intermediate features
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='relu', padding='same', name=str(hgid) + '_conv_1x1_x1')(
        rf1)
    head = BatchNormalization()(head)

    # for head as intermediate supervision, use 'linear' as activation.
    head_parts = Conv2D(num_classes, kernel_size=(1, 1), activation='linear', padding='same',
                        name=str(hgid) + '_conv_1x1_parts')(head)

    # use linear activation
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                  name=str(hgid) + '_conv_1x1_x2')(head)
    head_m = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                    name=str(hgid) + '_conv_1x1_x3')(head_parts)

    head_next_stage = Add()([head, head_m, prelayerfeatures])
    return head_next_stage, head_parts

# %%
model = create_hourglass_network(num_classes=16, num_stacks=1, num_channels=32 , inres=(512, 512),
                            outres=(1,1), bottleneck=bottleneck_block)

# %%
model.summary()
# Out:
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x1 ( (None, 512, 512, 8)  16          input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 512, 512, 8)  32          front_residual_x1_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_3x3_x2 ( (None, 512, 512, 8)  584         batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 512, 512, 8)  32          front_residual_x1_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x3 ( (None, 512, 512, 16) 144         batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# front_residual_x1skip (Conv2D)  (None, 512, 512, 16) 32          input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 512, 512, 16) 64          front_residual_x1_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x1_residual (Add (None, 512, 512, 16) 0           front_residual_x1skip[0][0]
#                                                                  batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x1 ( (None, 512, 512, 8)  136         front_residual_x1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 512, 512, 8)  32          front_residual_x2_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_3x3_x2 ( (None, 512, 512, 8)  584         batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 512, 512, 8)  32          front_residual_x2_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x3 ( (None, 512, 512, 16) 144         batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 512, 512, 16) 64          front_residual_x2_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x2_residual (Add (None, 512, 512, 16) 0           front_residual_x1_residual[0][0]
#                                                                  batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x1 ( (None, 512, 512, 16) 272         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 512, 512, 16) 64          front_residual_x3_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_3x3_x2 ( (None, 512, 512, 16) 2320        batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 512, 512, 16) 64          front_residual_x3_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x3 ( (None, 512, 512, 32) 544         batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# front_residual_x3skip (Conv2D)  (None, 512, 512, 32) 544         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 512, 512, 32) 128         front_residual_x3_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x3_residual (Add (None, 512, 512, 32) 0           front_residual_x3skip[0][0]
#                                                                  batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x1 (Conv2D)     (None, 512, 512, 16) 528         front_residual_x3_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 512, 512, 16) 64          hg0_l1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_3x3_x2 (Conv2D)     (None, 512, 512, 16) 2320        batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 512, 512, 16) 64          hg0_l1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x3 (Conv2D)     (None, 512, 512, 32) 544         batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 512, 512, 32) 128         hg0_l1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l1_residual (Add)           (None, 512, 512, 32) 0           front_residual_x3_residual[0][0]
#                                                                  batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 256, 256, 32) 0           hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x1 (Conv2D)     (None, 256, 256, 16) 528         max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 256, 256, 16) 64          hg0_l2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_3x3_x2 (Conv2D)     (None, 256, 256, 16) 2320        batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 256, 256, 16) 64          hg0_l2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x3 (Conv2D)     (None, 256, 256, 32) 544         batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 256, 256, 32) 128         hg0_l2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l2_residual (Add)           (None, 256, 256, 32) 0           max_pooling2d_16[0][0]
#                                                                  batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 128, 128, 32) 0           hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x1 (Conv2D)     (None, 128, 128, 16) 528         max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 128, 128, 16) 64          hg0_l4_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_3x3_x2 (Conv2D)     (None, 128, 128, 16) 2320        batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 128, 128, 16) 64          hg0_l4_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x3 (Conv2D)     (None, 128, 128, 32) 544         batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 128, 128, 32) 128         hg0_l4_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l4_residual (Add)           (None, 128, 128, 32) 0           max_pooling2d_17[0][0]
#                                                                  batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 64, 64, 32)   0           hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x1 (Conv2D)     (None, 64, 64, 16)   528         max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 64, 64, 16)   64          hg0_l8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_3x3_x2 (Conv2D)     (None, 64, 64, 16)   2320        batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 64, 64, 16)   64          hg0_l8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x3 (Conv2D)     (None, 64, 64, 32)   544         batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 64, 64, 32)   128         hg0_l8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l8_residual (Add)           (None, 64, 64, 32)   0           max_pooling2d_18[0][0]
#                                                                  batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x1 (Conv2D)   (None, 64, 64, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 64, 64, 16)   64          0_lf8_x1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_3x3_x2 (Conv2D)   (None, 64, 64, 16)   2320        batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 64, 64, 16)   64          0_lf8_x1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x3 (Conv2D)   (None, 64, 64, 32)   544         batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 64, 64, 32)   128         0_lf8_x1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_residual (Add)         (None, 64, 64, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x1 (Conv2D)   (None, 64, 64, 16)   528         0_lf8_x1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 64, 64, 16)   64          0_lf8_x2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_3x3_x2 (Conv2D)   (None, 64, 64, 16)   2320        batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 64, 64, 16)   64          0_lf8_x2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x3 (Conv2D)   (None, 64, 64, 32)   544         batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 64, 64, 32)   128         0_lf8_x2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_residual (Add)         (None, 64, 64, 32)   0           0_lf8_x1_residual[0][0]
#                                                                  batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x1 (Conv2D)   (None, 64, 64, 16)   528         0_lf8_x2_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x1 (Conv2D)      (None, 64, 64, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 64, 64, 16)   64          0_lf8_x3_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 64, 64, 16)   64          0_lf8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x1 (Co (None, 128, 128, 16) 528         hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_3x3_x2 (Conv2D)   (None, 64, 64, 16)   2320        batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_3x3_x2 (Conv2D)      (None, 64, 64, 16)   2320        batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 128, 128, 16) 64          hg0_rf4_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 64, 64, 16)   64          0_lf8_x3_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 64, 64, 16)   64          0_lf8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_3x3_x2 (Co (None, 128, 128, 16) 2320        batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x3 (Conv2D)   (None, 64, 64, 32)   544         batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x3 (Conv2D)      (None, 64, 64, 32)   544         batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 128, 128, 16) 64          hg0_rf4_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 64, 64, 32)   128         0_lf8_x3_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 64, 64, 32)   128         0_lf8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x3 (Co (None, 128, 128, 32) 544         batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_residual (Add)         (None, 64, 64, 32)   0           0_lf8_x2_residual[0][0]
#                                                                  batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# 0_lf8_residual (Add)            (None, 64, 64, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 128, 128, 32) 128         hg0_rf4_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 64, 64, 32)   0           0_lf8_x3_residual[0][0]
#                                                                  0_lf8_residual[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_residual (Add)  (None, 128, 128, 32) 0           hg0_l4_residual[0][0]
#                                                                  batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 128, 128, 32) 0           add_20[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 128, 128, 32) 0           hg0_rf4_connect_residual[0][0]
#                                                                  up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 128, 128, 16) 528         add_21[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x1 (Co (None, 256, 256, 16) 528         hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 128, 128, 16) 64          hg0_rf4_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 256, 256, 16) 64          hg0_rf2_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_3x3_x (None, 128, 128, 16) 2320        batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_3x3_x2 (Co (None, 256, 256, 16) 2320        batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 128, 128, 16) 64          hg0_rf4_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 256, 256, 16) 64          hg0_rf2_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 128, 128, 32) 544         batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x3 (Co (None, 256, 256, 32) 544         batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 128, 128, 32) 128         hg0_rf4_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 256, 256, 32) 128         hg0_rf2_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_residual ( (None, 128, 128, 32) 0           add_21[0][0]
#                                                                  batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_residual (Add)  (None, 256, 256, 32) 0           hg0_l2_residual[0][0]
#                                                                  batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 256, 256, 32) 0           hg0_rf4_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 256, 256, 32) 0           hg0_rf2_connect_residual[0][0]
#                                                                  up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 256, 256, 16) 528         add_22[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x1 (Co (None, 512, 512, 16) 528         hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 256, 256, 16) 64          hg0_rf2_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 512, 512, 16) 64          hg0_rf1_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_3x3_x (None, 256, 256, 16) 2320        batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_3x3_x2 (Co (None, 512, 512, 16) 2320        batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 256, 256, 16) 64          hg0_rf2_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 512, 512, 16) 64          hg0_rf1_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 256, 256, 32) 544         batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x3 (Co (None, 512, 512, 32) 544         batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 256, 256, 32) 128         hg0_rf2_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 512, 512, 32) 128         hg0_rf1_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_residual ( (None, 256, 256, 32) 0           add_22[0][0]
#                                                                  batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_residual (Add)  (None, 512, 512, 32) 0           hg0_l1_residual[0][0]
#                                                                  batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 512, 512, 32) 0           hg0_rf2_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 512, 512, 32) 0           hg0_rf1_connect_residual[0][0]
#                                                                  up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 512, 512, 16) 528         add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 512, 512, 16) 64          hg0_rf1_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_3x3_x (None, 512, 512, 16) 2320        batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 512, 512, 16) 64          hg0_rf1_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 512, 512, 32) 544         batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 512, 512, 32) 128         hg0_rf1_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_residual ( (None, 512, 512, 32) 0           add_23[0][0]
#                                                                  batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_x1 (Conv2D)          (None, 512, 512, 32) 1056        hg0_rf1_connect_conv_residual[0][
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 512, 512, 32) 128         0_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_parts (Conv2D)       (None, 512, 512, 16) 528         batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 512, 512, 16) 64          0_conv_1x1_parts[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 1)  17          batch_normalization_276[0][0]
# ==================================================================================================
# Total params: 58,697
# Trainable params: 56,553
# Non-trainable params: 2,144
# __________________________________________________________________________________________________
