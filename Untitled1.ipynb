# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import mean_squared_error
import tensorflow.keras.backend as K


def create_hourglass_network(num_classes, num_stacks, num_channels, inres, outres, bottleneck):
    input = Input(shape=(inres[0], inres[1], 1))

    front_features = create_front_module(input, num_channels, bottleneck)

    head_next_stage = front_features

    outputs = []
    for i in range(num_stacks):
        head_next_stage, head_to_loss = hourglass_module(head_next_stage, num_classes, num_channels, bottleneck, i)
        outputs.append(head_to_loss)
        a = Flatten()(outputs[-1])
        a = Dense(num_classes, activation=None)(a)
        

    model = Model(inputs=input, outputs=a)
    rms = RMSprop(lr=5e-4)
    model.compile(optimizer=rms, loss=mean_squared_error, metrics=["accuracy"])
    
    

    return model


def hourglass_module(bottom, num_classes, num_channels, bottleneck, hgid):
    # create left features , f1, f2, f4, and f8
    left_features = create_left_half_blocks(bottom, bottleneck, hgid, num_channels)

    # create right features, connect with left features
    rf1 = create_right_half_blocks(left_features, bottleneck, hgid, num_channels)

    # add 1x1 conv with two heads, head_next_stage is sent to next stage
    # head_parts is used for intermediate supervision
    head_next_stage, head_parts = create_heads(bottom, rf1, num_classes, hgid, num_channels)

    return head_next_stage, head_parts


def bottleneck_block(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                       name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = Conv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = Conv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def bottleneck_mobile(bottom, num_out_channels, block_name):
    # skip layer
    if K.int_shape(bottom)[-1] == num_out_channels:
        _skip = bottom
    else:
        _skip = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                                name=block_name + 'skip')(bottom)

    # residual: 3 conv blocks,  [num_out_channels/2  -> num_out_channels/2 -> num_out_channels]
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x1')(bottom)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels / 2, kernel_size=(3, 3), activation='relu', padding='same',
                         name=block_name + '_conv_3x3_x2')(_x)
    _x = BatchNormalization()(_x)
    _x = SeparableConv2D(num_out_channels, kernel_size=(1, 1), activation='relu', padding='same',
                         name=block_name + '_conv_1x1_x3')(_x)
    _x = BatchNormalization()(_x)
    _x = Add(name=block_name + '_residual')([_skip, _x])

    return _x


def create_front_module(input, num_channels, bottleneck):
    # front module, input to 1/4 resolution
    # 1 7x7 conv + maxpooling
    # 3 residual block

    _x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same', activation='relu', name='front_conv_1x1_x1')(
        input)
    _x = BatchNormalization()(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(_x)

    _x = bottleneck(_x, num_channels // 2, 'front_residual_x2')
    _x = bottleneck(_x, num_channels, 'front_residual_x3')

    return _x


def create_left_half_blocks(bottom, bottleneck, hglayer, num_channels):
    # create left half blocks for hourglass module
    # f1, f2, f4 , f8 : 1, 1/2, 1/4 1/8 resolution

    hgname = 'hg' + str(hglayer)

    f1 = bottleneck(bottom, num_channels, hgname + '_l1')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f1)

    f2 = bottleneck(_x, num_channels, hgname + '_l2')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f2)

    f4 = bottleneck(_x, num_channels, hgname + '_l4')
    _x = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(f4)

    f8 = bottleneck(_x, num_channels, hgname + '_l8')

    return (f1, f2, f4, f8)


def connect_left_to_right(left, right, bottleneck, name, num_channels):
    '''
    :param left: connect left feature to right feature
    :param name: layer name
    :return:
    '''
    # left -> 1 bottlenect
    # right -> upsampling
    # Add   -> left + right

    _xleft = bottleneck(left, num_channels, name + '_connect')
    _xright = UpSampling2D()(right)
    add = Add()([_xleft, _xright])
    out = bottleneck(add, num_channels, name + '_connect_conv')
    return out


def bottom_layer(lf8, bottleneck, hgid, num_channels):
    # blocks in lowest resolution
    # 3 bottlenect blocks + Add

    lf8_connect = bottleneck(lf8, num_channels, str(hgid) + "_lf8")

    _x = bottleneck(lf8, num_channels, str(hgid) + "_lf8_x1")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x2")
    _x = bottleneck(_x, num_channels, str(hgid) + "_lf8_x3")

    rf8 = Add()([_x, lf8_connect])

    return rf8


def create_right_half_blocks(leftfeatures, bottleneck, hglayer, num_channels):  #branch_add
    lf1, lf2, lf4, lf8 = leftfeatures

    rf8 = bottom_layer(lf8, bottleneck, hglayer, num_channels)

    rf4 = connect_left_to_right(lf4, rf8, bottleneck, 'hg' + str(hglayer) + '_rf4', num_channels)

    rf2 = connect_left_to_right(lf2, rf4, bottleneck, 'hg' + str(hglayer) + '_rf2', num_channels)

    rf1 = connect_left_to_right(lf1, rf2, bottleneck, 'hg' + str(hglayer) + '_rf1', num_channels)

    return rf1


def create_heads(prelayerfeatures, rf1, num_classes, hgid, num_channels):
    # two head, one head to next stage, one head to intermediate features
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='relu', padding='same', name=str(hgid) + '_conv_1x1_x1')(
        rf1)
    head = BatchNormalization()(head)

    # for head as intermediate supervision, use 'linear' as activation.
    head_parts = Conv2D(num_classes, kernel_size=(1, 1), activation='linear', padding='same',
                        name=str(hgid) + '_conv_1x1_parts')(head)

    # use linear activation
    head = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                  name=str(hgid) + '_conv_1x1_x2')(head)
    head_m = Conv2D(num_channels, kernel_size=(1, 1), activation='linear', padding='same',
                    name=str(hgid) + '_conv_1x1_x3')(head_parts)

    head_next_stage = Add()([head, head_m, prelayerfeatures])
    return head_next_stage, head_parts


def euclidean_loss(x, y):
    return K.sqrt(K.sum(K.square(x - y)))

# %%
model = create_hourglass_network(num_classes=16, num_stacks=1, num_channels=32 , inres=(512, 512),
                            outres=(1,1), bottleneck=bottleneck_block)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# front_conv_1x1_x1 (Conv2D)      (None, 256, 256, 64) 3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         front_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x1 ( (None, 256, 256, 8)  520         batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 8)  32          front_residual_x1_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_3x3_x2 ( (None, 256, 256, 8)  584         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 8)  32          front_residual_x1_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x1_conv_1x1_x3 ( (None, 256, 256, 16) 144         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# front_residual_x1skip (Conv2D)  (None, 256, 256, 16) 1040        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 16) 64          front_residual_x1_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x1_residual (Add (None, 256, 256, 16) 0           front_residual_x1skip[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           front_residual_x1_residual[0][0]
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x1 ( (None, 128, 128, 8)  136         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 8)  32          front_residual_x2_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_3x3_x2 ( (None, 128, 128, 8)  584         batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 8)  32          front_residual_x2_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x2_conv_1x1_x3 ( (None, 128, 128, 16) 144         batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 16) 64          front_residual_x2_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x2_residual (Add (None, 128, 128, 16) 0           max_pooling2d[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x1 ( (None, 128, 128, 16) 272         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 16) 64          front_residual_x3_conv_1x1_x1[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_3x3_x2 ( (None, 128, 128, 16) 2320        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 16) 64          front_residual_x3_conv_3x3_x2[0][
# __________________________________________________________________________________________________
# front_residual_x3_conv_1x1_x3 ( (None, 128, 128, 32) 544         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# front_residual_x3skip (Conv2D)  (None, 128, 128, 32) 544         front_residual_x2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 32) 128         front_residual_x3_conv_1x1_x3[0][
# __________________________________________________________________________________________________
# front_residual_x3_residual (Add (None, 128, 128, 32) 0           front_residual_x3skip[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x1 (Conv2D)     (None, 128, 128, 16) 528         front_residual_x3_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 16) 64          hg0_l1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_3x3_x2 (Conv2D)     (None, 128, 128, 16) 2320        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 16) 64          hg0_l1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l1_conv_1x1_x3 (Conv2D)     (None, 128, 128, 32) 544         batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 32) 128         hg0_l1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l1_residual (Add)           (None, 128, 128, 32) 0           front_residual_x3_residual[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x1 (Conv2D)     (None, 64, 64, 16)   528         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 16)   64          hg0_l2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_3x3_x2 (Conv2D)     (None, 64, 64, 16)   2320        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 16)   64          hg0_l2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l2_conv_1x1_x3 (Conv2D)     (None, 64, 64, 32)   544         batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 32)   128         hg0_l2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l2_residual (Add)           (None, 64, 64, 32)   0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x1 (Conv2D)     (None, 32, 32, 16)   528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 16)   64          hg0_l4_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_3x3_x2 (Conv2D)     (None, 32, 32, 16)   2320        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 16)   64          hg0_l4_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l4_conv_1x1_x3 (Conv2D)     (None, 32, 32, 32)   544         batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 32)   128         hg0_l4_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l4_residual (Add)           (None, 32, 32, 32)   0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)   0           hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x1 (Conv2D)     (None, 16, 16, 16)   528         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 16)   64          hg0_l8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_3x3_x2 (Conv2D)     (None, 16, 16, 16)   2320        batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 16)   64          hg0_l8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_l8_conv_1x1_x3 (Conv2D)     (None, 16, 16, 32)   544         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 32)   128         hg0_l8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_l8_residual (Add)           (None, 16, 16, 32)   0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 16)   64          0_lf8_x1_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 16)   64          0_lf8_x1_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 32)   128         0_lf8_x1_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x1_residual (Add)         (None, 16, 16, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         0_lf8_x1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 16)   64          0_lf8_x2_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 16)   64          0_lf8_x2_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 32)   128         0_lf8_x2_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x2_residual (Add)         (None, 16, 16, 32)   0           0_lf8_x1_residual[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x1 (Conv2D)   (None, 16, 16, 16)   528         0_lf8_x2_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x1 (Conv2D)      (None, 16, 16, 16)   528         hg0_l8_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 16)   64          0_lf8_x3_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 16)   64          0_lf8_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x1 (Co (None, 32, 32, 16)   528         hg0_l4_residual[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_3x3_x2 (Conv2D)   (None, 16, 16, 16)   2320        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_3x3_x2 (Conv2D)      (None, 16, 16, 16)   2320        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 16)   64          hg0_rf4_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 16)   64          0_lf8_x3_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 16)   64          0_lf8_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_3x3_x2 (Co (None, 32, 32, 16)   2320        batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_conv_1x1_x3 (Conv2D)   (None, 16, 16, 32)   544         batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# 0_lf8_conv_1x1_x3 (Conv2D)      (None, 16, 16, 32)   544         batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 16)   64          hg0_rf4_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 32)   128         0_lf8_x3_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 32)   128         0_lf8_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_1x1_x3 (Co (None, 32, 32, 32)   544         batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# 0_lf8_x3_residual (Add)         (None, 16, 16, 32)   0           0_lf8_x2_residual[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# 0_lf8_residual (Add)            (None, 16, 16, 32)   0           hg0_l8_residual[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 32)   128         hg0_rf4_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 32)   0           0_lf8_x3_residual[0][0]
#                                                                  0_lf8_residual[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_residual (Add)  (None, 32, 32, 32)   0           hg0_l4_residual[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           hg0_rf4_connect_residual[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 16)   528         add_1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x1 (Co (None, 64, 64, 16)   528         hg0_l2_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 16)   64          hg0_rf4_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 64, 16)   64          hg0_rf2_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_3x3_x (None, 32, 32, 16)   2320        batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_3x3_x2 (Co (None, 64, 64, 16)   2320        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 16)   64          hg0_rf4_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 64, 16)   64          hg0_rf2_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_conv_1x1_x (None, 32, 32, 32)   544         batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_1x1_x3 (Co (None, 64, 64, 32)   544         batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 32)   128         hg0_rf4_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 64, 64, 32)   128         hg0_rf2_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf4_connect_conv_residual ( (None, 32, 32, 32)   0           add_1[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_residual (Add)  (None, 64, 64, 32)   0           hg0_l2_residual[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 32)   0           hg0_rf4_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           hg0_rf2_connect_residual[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 16)   528         add_2[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x1 (Co (None, 128, 128, 16) 528         hg0_l1_residual[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 64, 64, 16)   64          hg0_rf2_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 128, 128, 16) 64          hg0_rf1_connect_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_3x3_x (None, 64, 64, 16)   2320        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_3x3_x2 (Co (None, 128, 128, 16) 2320        batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 64, 64, 16)   64          hg0_rf2_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 128, 128, 16) 64          hg0_rf1_connect_conv_3x3_x2[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_conv_1x1_x (None, 64, 64, 32)   544         batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_1x1_x3 (Co (None, 128, 128, 32) 544         batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 64, 64, 32)   128         hg0_rf2_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 128, 128, 32) 128         hg0_rf1_connect_conv_1x1_x3[0][0]
# __________________________________________________________________________________________________
# hg0_rf2_connect_conv_residual ( (None, 64, 64, 32)   0           add_2[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_residual (Add)  (None, 128, 128, 32) 0           hg0_l1_residual[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 32) 0           hg0_rf2_connect_conv_residual[0][
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 32) 0           hg0_rf1_connect_residual[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 16) 528         add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 128, 16) 64          hg0_rf1_connect_conv_conv_1x1_x1[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_3x3_x (None, 128, 128, 16) 2320        batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128, 128, 16) 64          hg0_rf1_connect_conv_conv_3x3_x2[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_conv_1x1_x (None, 128, 128, 32) 544         batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 128, 128, 32) 128         hg0_rf1_connect_conv_conv_1x1_x3[
# __________________________________________________________________________________________________
# hg0_rf1_connect_conv_residual ( (None, 128, 128, 32) 0           add_3[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_x1 (Conv2D)          (None, 128, 128, 32) 1056        hg0_rf1_connect_conv_residual[0][
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 128, 128, 32) 128         0_conv_1x1_x1[0][0]
# __________________________________________________________________________________________________
# 0_conv_1x1_parts (Conv2D)       (None, 128, 128, 16) 528         batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 262144)       0           0_conv_1x1_parts[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           4194320     flatten[0][0]
# ==================================================================================================
# Total params: 4,257,904
# Trainable params: 4,255,664
# Non-trainable params: 2,240
# __________________________________________________________________________________________________

# %%
5/2
# Out:
# 2.5

# %%
4/2
# Out:
# 2.0
